# %%
idades = ['20', '30', '40', '50', '60']

print(idades)
# Out:
# ['20', '30', '40', '50', '60']

# %%
# Exercicio 1

frutas = ['maçã', 'banana', 'laranja', 'uva', 'pera']
print(frutas)
# Out:
# ['maçã', 'banana', 'laranja', 'uva', 'pera']

# %%
print(frutas[0])  # Acessa o primeiro elemento
print(frutas[2])  # Acessa o terceiro elemento
# Out:
# maçã
# laranja

# %%
frutas.append('manga')  # Adiciona 'manga' ao final da lista
frutas.remove('banana')  # Remove 'banana' da lista
frutas.sort()  # Ordena a lista em ordem alfabética
frutas.reverse()  # Inverte a ordem da lista
frutas.insert(1, 'kiwi')  # Insere 'kiwi' na posição 1
frutas.pop()  # Remove o último elemento da lista
frutas.clear()  # Remove todos os elementos da lista
frutas_count = len(frutas)  # Conta o número de elementos na lista
frutas_index = frutas.index('laranja')  # Encontra o índice de 'laranja'
frutas_extend = frutas + ['abacaxi', 'coco']  # Extende a lista com novos elementos
frutas_slice = frutas[1:4]  # Fatiamento da lista do índice 1 ao 3
frutas_copy = frutas.copy()  # Cria uma cópia da lista
frutas_count_laranja = frutas.count('laranja')  # Conta quantas vezes 'laranja' aparece na lista
frutas.sort(reverse=True)  # Ordena a lista em ordem decrescente
frutas_remove_at_index = frutas.pop(2)  # Remove o elemento no índice 2
